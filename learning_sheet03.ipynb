# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import adabound # https://github.com/Luolc/AdaBound
import sys

from torch.utils.tensorboard import SummaryWriter

# For notificaiton
#import AppKit

# %% [markdown]
# # CNN - CIFAR-10

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper parameters
num_epochs = 100
batch_size = 64
learning_rate = 0.01
log_directory = f"runs/CIFAR10/AdaBound lr = {learning_rate}, epochs = {num_epochs}, batchsize ={batch_size}"
writer1  = SummaryWriter(log_directory)
#writer2 = SummaryWriter(log_directory)

# Loading dataset
# Since the dataset is in PIL (Python Imaging Library) form, tranform them into tensors of normalised range [-1, 1]
transform = transforms.Compose( # this transforms.compose combines multiple tranformations as one
    [
        transforms.ToTensor(), 
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ]
)

# The CIFAR10 tataset is avaliable in PyTorch
train_dataset = torchvision.datasets.CIFAR10(root='./cifar10Dataset', train=True,  download=True, transform=transform)
test_dataset  = torchvision.datasets.CIFAR10(root='./cifar10Dataset', train=False, download=True, transform=transform)

# Splitting the training and testing datasets into smaller batches
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = torch.utils.data.DataLoader(dataset=test_dataset,  batch_size=batch_size, shuffle=False)

classes = ('Plane', 'Car', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck')

# Checking a data sample 
example = iter(train_loader)
images, labels = example.next()

def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

imshow(torchvision.utils.make_grid(images))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        # Feature extraction layers
        self.conv1 = nn.Conv2d(3, 6, 5)     # Input 3 (RGB), 6 (outputs), 5 (kernel size)
        self.pool  = nn.MaxPool2d(2, 2)      # Kernel size of 2 with stride of 2
        self.conv2 = nn.Conv2d(6, 16, 5)    # Input 6 (conv1's output), 16 (outputs), 5 (kernel size)
        # Classification layers
        self.fc1   = nn.Linear(16*5*5, 120)   # Fully connected linear layer. 16 is the output of conv2 and 5x5 is
#                                             the output dimention after conv1->pool->conv2->pool. 
#                                             The process can be observed in the coming cells.
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)        # Output is 10 as we have 10 classes in the CIFAR-10 dataset

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16*5*5) # Flattening x. # -1 makes pytorch infer the dimensionality, which in this case is the number of batches (4).
# It does this by looking at the given dimentions, and inferring the last one using the amount of avaliable data/cells.
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)         # Don't apply softmax, as it's applied in the used criterion - nn.CrossEntropyLoss()
        return x
        
model = ConvNet().to(device)

criterion = nn.CrossEntropyLoss()
#optimiser = torch.optim.SGD(model.parameters(), lr=larning_rate)
optimiser = adabound.AdaBound(model.parameters(), lr=1e-6, final_lr=learning_rate)
#scheduler = torch.optim.lr_scheduler.StepLR(optimiser, step_size=num_epochs, gamma=0.1)

# Tensorboard
writer1.add_graph(model, images)
writer1.close()

# Doing the training now
n_total_steps = len(train_loader)

running_loss = 0
running_correct = 0
running_loss_test = 0

x = 1
steps_until_print = batch_size #(len(train_dataset))/x           # Log once per epoch/x
#print(f'One batch has {len(example)/batch_size} images\nPrint every {steps_until_print}')

for epoch in range(num_epochs):

    testing_batches = iter(test_loader) # For every epoch, we want to have tested the whole testing dataset once

    for i, (images, labels) in enumerate(train_loader):
        
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass
        optimiser.zero_grad()   # Clear old gradient values
        loss.backward()         # Calculate the gradients
        optimiser.step()        # Update the model's weights (these are the model parameters(), different from hyperparameters)

        with torch.no_grad():
            # Add loss to the running loss 
            running_loss = loss.item()
            _, predictions = torch.max(outputs, 1)                  # Evaluate along the 1st dimension

            running_correct = (predictions == labels).sum().item()  # We can call .item() as it's a tensor with one item

            if (i+1) % steps_until_print == 0:
                # Logging the loss
                writer1.add_scalar('Loss/training', running_loss/steps_until_print, epoch * n_total_steps + i) # label of the scalar, actual loss mean, current global step 
                # Adding the accuracy
                writer1.add_scalar('Accuracy/training', running_correct/batch_size*100, epoch * n_total_steps + i) # label of the scalar, actual loss mean, current global step 
                #running_loss = 0.0
                #running_correct = 0

            # If for every 5 epochs, test one batch. (test:train data ratio is split 1:5)
            if (i+1) % 5 == 0:
                test_images, test_labels = testing_batches.next()
                
                test_images = test_images.to(device)
                test_labels = test_labels.to(device)

                test_outputs = model(test_images)

                _, test_predictions = torch.max(test_outputs, 1)
                test_running_correct = (test_predictions == test_labels).sum().item()
                writer1.add_scalar('Accuracy/testing', test_running_correct/batch_size*100, epoch * n_total_steps + i) # label of the scalar, actual loss mean, current global step 

                test_loss = criterion(test_outputs, test_labels)
                test_running_loss = test_loss.item()
                writer1.add_scalar('Loss/testing', test_running_loss/len(test_labels), epoch * n_total_steps + i) # label of the scalar, actual loss mean, current global step

    # Logging the testing loss
    """for test_images, test_labels in testing_batches:
            test_images = test_images.to(device)
            test_labels = test_labels.to(device)

            test_outputs = model(test_images)
            loss = criterion(test_outputs, test_labels)
            running_loss_test = loss.item()
    
    writer1.add_scalar('Loss/testing', running_loss_test/len(test_labels), epoch * n_total_steps) # label of the scalar, actual loss mean, current global step 
    """
    #writer2.add_scalar('Loss/training', running_loss/steps_until_print, epoch * n_total_steps) # label of the scalar, actual loss mean, current global step
    print(f'Epoch {epoch+1}/{num_epochs}, step {i+1}/{n_total_steps}, loss = {loss.item():.5f}, testing loss = {running_loss_test}')

    #print(f'Finished epoch {epoch+1}/{num_epochs}')
    #scheduler.step()

print("Training is done")
#AppKit.NSBeep()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/adabound/adabound.py:94: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   exp_avg.mul_(beta1).add_(1 - beta1, grad)
# Epoch 1/100, step 782/782, loss = 2.31172, testing loss = 0
# Epoch 2/100, step 782/782, loss = 2.30800, testing loss = 0
# Epoch 3/100, step 782/782, loss = 2.27265, testing loss = 0
# Epoch 4/100, step 782/782, loss = 1.83156, testing loss = 0
# Epoch 5/100, step 782/782, loss = 1.83353, testing loss = 0
# Epoch 6/100, step 782/782, loss = 1.68488, testing loss = 0
# Epoch 7/100, step 782/782, loss = 1.34473, testing loss = 0
# Epoch 8/100, step 782/782, loss = 2.04218, testing loss = 0
# Epoch 9/100, step 782/782, loss = 1.62080, testing loss = 0
# Epoch 10/100, step 782/782, loss = 1.27133, testing loss = 0
# Epoch 11/100, step 782/782, loss = 1.43312, testing loss = 0
# Epoch 12/100, step 782/782, loss = 1.51641, testing loss = 0
# Epoch 13/100, step 782/782, loss = 1.48975, testing loss = 0
# Epoch 14/100, step 782/782, loss = 1.34607, testing loss = 0
# Epoch 15/100, step 782/782, loss = 1.58468, testing loss = 0
# Epoch 16/100, step 782/782, loss = 1.23705, testing loss = 0
# Epoch 17/100, step 782/782, loss = 1.13282, testing loss = 0
# Epoch 18/100, step 782/782, loss = 1.17146, testing loss = 0
# Epoch 19/100, step 782/782, loss = 0.94796, testing loss = 0
# Epoch 20/100, step 782/782, loss = 1.02084, testing loss = 0
# Epoch 21/100, step 782/782, loss = 0.74299, testing loss = 0
# Epoch 22/100, step 782/782, loss = 0.97996, testing loss = 0
# Epoch 23/100, step 782/782, loss = 0.89612, testing loss = 0
# Epoch 24/100, step 782/782, loss = 0.63094, testing loss = 0
# Epoch 25/100, step 782/782, loss = 1.33325, testing loss = 0
# Epoch 26/100, step 782/782, loss = 1.18254, testing loss = 0
# Epoch 27/100, step 782/782, loss = 1.04282, testing loss = 0
# Epoch 28/100, step 782/782, loss = 0.78865, testing loss = 0
# Epoch 29/100, step 782/782, loss = 0.79477, testing loss = 0
# Epoch 30/100, step 782/782, loss = 0.77544, testing loss = 0
# Epoch 31/100, step 782/782, loss = 0.91470, testing loss = 0
# Epoch 32/100, step 782/782, loss = 0.41347, testing loss = 0
# Epoch 33/100, step 782/782, loss = 0.87683, testing loss = 0
# Epoch 34/100, step 782/782, loss = 0.63830, testing loss = 0
# Epoch 35/100, step 782/782, loss = 0.93092, testing loss = 0
# Epoch 36/100, step 782/782, loss = 0.48119, testing loss = 0
# Epoch 37/100, step 782/782, loss = 0.58536, testing loss = 0
# Epoch 38/100, step 782/782, loss = 0.95605, testing loss = 0
# Epoch 39/100, step 782/782, loss = 0.93129, testing loss = 0
# Epoch 40/100, step 782/782, loss = 0.99159, testing loss = 0
# Epoch 41/100, step 782/782, loss = 0.74599, testing loss = 0
# Epoch 42/100, step 782/782, loss = 0.56859, testing loss = 0
# Epoch 43/100, step 782/782, loss = 0.62916, testing loss = 0
# Epoch 44/100, step 782/782, loss = 0.86778, testing loss = 0
# Epoch 45/100, step 782/782, loss = 0.53178, testing loss = 0
# Epoch 46/100, step 782/782, loss = 0.78866, testing loss = 0
# Epoch 47/100, step 782/782, loss = 1.27785, testing loss = 0
# Epoch 48/100, step 782/782, loss = 0.92600, testing loss = 0
# Epoch 49/100, step 782/782, loss = 1.04103, testing loss = 0
# Epoch 50/100, step 782/782, loss = 0.59199, testing loss = 0
# Epoch 51/100, step 782/782, loss = 0.48401, testing loss = 0
# Epoch 52/100, step 782/782, loss = 0.50725, testing loss = 0
# Epoch 53/100, step 782/782, loss = 0.85299, testing loss = 0
# Epoch 54/100, step 782/782, loss = 0.32472, testing loss = 0
# Epoch 55/100, step 782/782, loss = 0.35004, testing loss = 0
# Epoch 56/100, step 782/782, loss = 0.94212, testing loss = 0
# Epoch 57/100, step 782/782, loss = 0.57337, testing loss = 0
# Epoch 58/100, step 782/782, loss = 0.41472, testing loss = 0
# Epoch 59/100, step 782/782, loss = 0.53925, testing loss = 0
# Epoch 60/100, step 782/782, loss = 0.91122, testing loss = 0
# Epoch 61/100, step 782/782, loss = 0.50048, testing loss = 0
# Epoch 62/100, step 782/782, loss = 0.26484, testing loss = 0
# Epoch 63/100, step 782/782, loss = 0.46884, testing loss = 0
# Epoch 64/100, step 782/782, loss = 1.12634, testing loss = 0
# Epoch 65/100, step 782/782, loss = 0.83816, testing loss = 0
# Epoch 66/100, step 782/782, loss = 0.33658, testing loss = 0
# Epoch 67/100, step 782/782, loss = 0.50557, testing loss = 0
# Epoch 68/100, step 782/782, loss = 0.57417, testing loss = 0
# Epoch 69/100, step 782/782, loss = 0.31455, testing loss = 0
# Epoch 70/100, step 782/782, loss = 0.59466, testing loss = 0
# Epoch 71/100, step 782/782, loss = 0.84896, testing loss = 0
# Epoch 72/100, step 782/782, loss = 0.45176, testing loss = 0
# Epoch 73/100, step 782/782, loss = 0.54369, testing loss = 0
# Epoch 74/100, step 782/782, loss = 0.74904, testing loss = 0
# Epoch 75/100, step 782/782, loss = 0.62175, testing loss = 0
# Epoch 76/100, step 782/782, loss = 0.74472, testing loss = 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kevork/Documents/Uni/6.Semester/Project/learning_sheet03.ipynb Cell 4' in <module>
#      <a href='vscode-notebook-cell:/Users/kevork/Documents/Uni/6.Semester/Project/learning_sheet03.ipynb#ch0000003?line=45'>46</a> for epoch in range(num_epochs):
#      <a href='vscode-notebook-cell:/Users/kevork/Documents/Uni/6.Semester/Project/learning_sheet03.ipynb#ch0000003?line=47'>48</a>     testing_batches = iter(test_loader) # For every epoch, we want to have tested the whole testing dataset once
# ---> <a href='vscode-notebook-cell:/Users/kevork/Documents/Uni/6.Semester/Project/learning_sheet03.ipynb#ch0000003?line=49'>50</a>     for i, (images, labels) in enumerate(train_loader):
#      <a href='vscode-notebook-cell:/Users/kevork/Documents/Uni/6.Semester/Project/learning_sheet03.ipynb#ch0000003?line=51'>52</a>         images = images.to(device)
#      <a href='vscode-notebook-cell:/Users/kevork/Documents/Uni/6.Semester/Project/learning_sheet03.ipynb#ch0000003?line=52'>53</a>         labels = labels.to(device)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=518'>519</a> if self._sampler_iter is None:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=519'>520</a>     self._reset()
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=520'>521</a> data = self._next_data()
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=521'>522</a> self._num_yielded += 1
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=522'>523</a> if self._dataset_kind == _DatasetKind.Iterable and \
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=523'>524</a>         self._IterableDataset_len_called is not None and \
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=524'>525</a>         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py:561, in _SingleProcessDataLoaderIter._next_data(self)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=558'>559</a> def _next_data(self):
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=559'>560</a>     index = self._next_index()  # may raise StopIteration
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=560'>561</a>     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=561'>562</a>     if self._pin_memory:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/dataloader.py?line=562'>563</a>         data = _utils.pin_memory.pin_memory(data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/cifar.py:121, in CIFAR10.__getitem__(self, index)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/cifar.py?line=117'>118</a> img = Image.fromarray(img)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/cifar.py?line=119'>120</a> if self.transform is not None:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/cifar.py?line=120'>121</a>     img = self.transform(img)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/cifar.py?line=122'>123</a> if self.target_transform is not None:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/datasets/cifar.py?line=123'>124</a>     target = self.target_transform(target)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py:61, in Compose.__call__(self, img)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=58'>59</a> def __call__(self, img):
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=59'>60</a>     for t in self.transforms:
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=60'>61</a>         img = t(img)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=61'>62</a>     return img
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1097'>1098</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1098'>1099</a> # this function, and just call forward.
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1099'>1100</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1100'>1101</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1101'>1102</a>     return forward_call(*input, **kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1102'>1103</a> # Do not call functions when jit is used
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py?line=1103'>1104</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py:226, in Normalize.forward(self, tensor)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=217'>218</a> def forward(self, tensor: Tensor) -> Tensor:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=218'>219</a>     """
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=219'>220</a>     Args:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=220'>221</a>         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=223'>224</a>         Tensor: Normalized Tensor image.
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=224'>225</a>     """
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/transforms.py?line=225'>226</a>     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/functional.py:351, in normalize(tensor, mean, std, inplace)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/functional.py?line=348'>349</a> if std.ndim == 1:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/functional.py?line=349'>350</a>     std = std.view(-1, 1, 1)
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/functional.py?line=350'>351</a> tensor.sub_(mean).div_(std)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/pytorch/lib/python3.8/site-packages/torchvision/transforms/functional.py?line=351'>352</a> return tensor
#
# KeyboardInterrupt:

# %% [markdown]
# # Why 16\*5\*5 in fc1?

# %%
def output_dimentions(W, F, P, S): # To read more, look at "Calculating the output dimentions" in the HackMD: https://hackmd.io/@6GXCH802RhyTNfXCGTWmOA/BJC32s5RK
#   W = input size, F = filter/kernel size, P = padding, S = stride
    return (W-F+2*P)/S + 1

# After conv1
output_dimentions(W=32, F=5, P=0, S=1) # Will have 6 outputs
# Out:
# 28.0

# %%
# After pool
output_dimentions(W=28, F=2, P=0, S=2) # Will have 6 outputs
# Out:
# 14.0

# %%
# After conv2
output_dimentions(W=14, F=5, P=0, S=1) # Will have 16 outputs
# Out:
# 10.0

# %%
# After pool again
output_dimentions(W=10, F=2, P=0, S=2) # Will have 16 outputs
# Out:
# 5.0

# %%
# Validation

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predictions = torch.max(outputs, 1)
        n_samples += labels.shape[0]
        n_correct += (predictions == labels).sum().item()

    accuracy = 100 * n_correct / n_samples
    print(f"Accuracy = {accuracy}")
# Out:
# Accuracy = 64.68

# %%
# Detailed validation - accuracy for each class

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    n_class_correct = [0 for i in range(10)]
    n_class_samples = [0 for i in range(10)]
    for images, labels in test_loader:
        
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predictions = torch.max(outputs, 1)  # torch.max returns (value, index)
        n_samples += labels.shape[0]
        n_correct += (predictions == labels).sum().item()

        for i in range(len(labels)):
            label = labels[i]
            pred = predictions[i]
            if(pred == label):
                n_class_correct[label] += 1
            n_class_samples[label] += 1

    accuracy = 100 * n_correct / n_samples
    print(f"General network accuracy = {accuracy}")

    for i in range(10):
        accuracy = 100.0 * n_class_correct[i] / n_class_samples[i]
        print(f'{classes[i]} class accuracy: \t \t {accuracy}%')
# Out:
# General network accuracy = 64.68
# Plane class accuracy: 	 	 69.6%
# Car class accuracy: 	 	 81.2%
# Bird class accuracy: 	 	 45.1%
# Cat class accuracy: 	 	 44.0%
# Deer class accuracy: 	 	 61.8%
# Dog class accuracy: 	 	 54.0%
# Frog class accuracy: 	 	 76.7%
# Horse class accuracy: 	 	 70.9%
# Ship class accuracy: 	 	 69.0%
# Truck class accuracy: 	 	 74.5%
